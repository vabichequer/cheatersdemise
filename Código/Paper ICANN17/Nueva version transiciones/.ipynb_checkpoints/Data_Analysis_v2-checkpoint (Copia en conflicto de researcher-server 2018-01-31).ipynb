# %% [markdown]
# <a name="Inicio"></a>
# # Data Analysis
#
# #### Autor: *Ángel Pérez Lemonche*
#
#
# ## Descripción general
#
# Este script utiliza las matrices de transición generadas en "Learning Paths with General *bricks*" con el fin de analizar el contenido de los datos para tomar futuras decisiones. Se puede realizar el mismo proceso utilizando **vectores de frecuencias**, normalizando por el número total de transiciones por semanas.

# %% [markdown]
# ### Importación de librerías y declaración de funciones

# %%
# Librerías generales
import numpy as np
import pandas as pd
import time

import sys
sys.path.insert(0, './lib/')

import imp
import myfunclib as mf
import auxiliares as ax
import transiciones as tr
import myValFunctions as vf
import myClusteringFunctions as cf


# Librerías propias
mf = imp.reload(mf)
ax = imp.reload(ax)
tr = imp.reload(tr)

vf = imp.reload(vf)
cf = imp.reload(cf)


pd.set_option('display.max_columns', 30)
from IPython.core.display import display, HTML, clear_output

# Librerías ML
from sklearn.cluster import KMeans

# Gráficos
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import style
#style.use("ggplot")
plt.rcParams["figure.figsize"] = [5,5]

# %% [markdown]
# Cargamos el fichero de entrada

# %%
# Diccionario semana

from datetime import datetime

### EDICION 1 ##

sem1 = datetime(2015,2,24)
sem2 = datetime(2015,3,3)
sem3 = datetime(2015,3,10)
sem4 = datetime(2015,3,17)
sem5 = datetime(2015,3,24)
sem6 = datetime(2015,3,31)
sem7 = datetime(2015,4,7)
sem8 = datetime(2015,4,14)

"""
###EDICION 2 ##

sem1 = datetime(2015,10,5)
sem2 = datetime(2015,10,12)
sem3 = datetime(2015,10,19)
sem4 = datetime(2015,10,26)
sem5 = datetime(2015,11,2)
sem6 = datetime(2015,11,9)
sem7 = datetime(2015,11,16)
sem8 = datetime(2015,11,23)
"""

SEM = {"Week1": [sem1, sem2],
       "Week2": [sem2, sem3],
       "Week3": [sem3, sem4],
       "Week4": [sem4, sem5],
       "Week5": [sem5, sem6],
       "Week6": [sem6, sem7]}

# %%
# Cargamos el fichero de trabajo
filename = "files/eventos_final.json"

eventsDFRaw = ax.readDataFile(filename)
eventsDFRawT = eventsDFRaw[eventsDFRaw['Usuario'] != '']
print("Tamaño:",len(eventsDFRaw))
print(eventsDFRaw.head(10))

# %%
eventsDFRaw = eventsDFRawT

# %%
# Filtrado por usuario: eliminamos los que hayan realizado
#  menos de 50 eventos en el curso
minEvents = 50

eventsDF = ax.dataFiltering(eventsDFRaw, minEvents);
print("Tamaño:",len(eventsDF))   
print(eventsDF.head(10))
# Out:
# Tamaño: 3138
#                                               Eventos  Usuario
# 1   [{'evento': 'load_video', 'tiempo': '2015-02-2...  6139738
# 2   [{'evento': 'load_video', 'tiempo': '2015-02-2...  6445710
# 4   [{'evento': 'load_video', 'tiempo': '2015-02-2...  6451715
# 6   [{'id_documento': '1.1. El entorno de desarrol...  2507090
# 8   [{'evento': 'load_video', 'tiempo': '2015-03-2...  6757226
# 10  [{'id_documento': '1.1. El entorno de desarrol...  6424889
# 15  [{'evento': 'load_video', 'tiempo': '2015-02-2...  6446854
# 16  [{'evento': 'load_video', 'tiempo': '2015-02-2...  6407163
# 17  [{'evento': 'load_video', 'tiempo': '2015-02-2...   458399
# 22  [{'evento': 'load_video', 'tiempo': '2015-02-2...  6539632

# %%
# Transiciones x semana
dicEvents = {
    'V' : ['play_video', 'seek_video'],
    'N' : ['problem_check'],
    'F' : ['edx.forum.searched', 'edx.forum.comment.created', 
           'edx.forum.response.created', 'edx.forum.thread.created'],
    'P' : ['openassessmentblock.self_assess'],
    'D' : ['textbook.pdf.chapter.navigated']
}

param = {'dicEvents': dicEvents,
        'assignationProblemCheckFile': 'IDNaturalProblemasEd1.csv',
        'ProblemCheckExceptions': ['J','X'],
        'useFreq': True}


startTotal = time.time()
transitionsDF = tr.Transitions(eventsDF, param)
print("%.2f"%((time.time() - startTotal)/60), 'minutos.')
# Out:
# 26.11 minutos.

# %%
transitionsDF.set_index('Usuario', inplace = True)

# %%
transitionsDF.to_csv('Transitionsdf.csv')

# %% [markdown]
# Reducción de dimensionalidad

# %%
# Selección de características

def MinMaxNorm(series):
    minim = series.min()
    maxim = series.max()
    return (series-minim)/(maxim-minim)

def TotalNorm(series):
    return series/series.sum()

def ZNorm(series):
    mean = series.mean()
    std = series.std()
    return (series-mean)/std

def featFrequency(featuresDF, info = .95, Normalize = None, Use_Rest = True, verbose = 1):
    import pandas as pd
    featDF = featuresDF.copy()
    returnDF = featuresDF.copy()

    if Normalize != None:
        featDF = featDF.apply(lambda x: Normalize(x), axis=0)
    
    suma = featDF.sum(axis=0)
    perinfo = (abs(suma)/abs(suma).sum()).sort_values(ascending=False)
    cumsum = perinfo.cumsum()

    featInfo = pd.concat([perinfo, cumsum], axis = 1)
    featInfo.columns = ['percentage', 'cumsum']
    featInfo['selection'] = (featInfo['cumsum'] < info)

    returnDF = returnDF[featInfo.index[featInfo.selection]]

    if Use_Rest:
        returnDF['Rest'] = featuresDF[featInfo.index[featInfo.selection == False]].sum(axis=1)
    
    if verbose > 0:
        print('From',len(featuresDF.columns),'to',len(returnDF.columns), 'selected features.')
        if verbose == 2:
            pd.options.display.float_format = '{:,.2f}%'.format
            toPrint = featInfo[['percentage','cumsum']].apply(lambda x: x*100)
            toPrint['selection'] = featInfo.selection
            display(toPrint)
    
    return returnDF, list(featInfo.index[featInfo.selection])

# %%
featuresDF, _ = featFrequency(transitionsDF, info = .96, verbose = 2)
# Out:
# From 36 to 12 selected features.
#       percentage  cumsum  selection
# V->V      20.98%  20.98%       True
# E->E      17.36%  38.33%       True
# A->A      13.62%  51.95%       True
# D->D      13.22%  65.18%       True
# V->E      12.69%  77.87%       True
# E->V      11.30%  89.17%       True
# D->V       2.50%  91.67%       True
# V->D       1.59%  93.25%       True
# A->V       0.92%  94.17%       True
# E->A       0.84%  95.01%       True
# F->F       0.79%  95.80%       True
# V->A       0.71%  96.51%      False
# F->V       0.44%  96.95%      False
# V->F       0.44%  97.39%      False
# E->D       0.43%  97.82%      False
# P->V       0.28%  98.10%      False
# D->E       0.26%  98.36%      False
# A->P       0.25%  98.61%      False
# A->D       0.22%  98.83%      False
# D->A       0.18%  99.01%      False
# A->F       0.14%  99.15%      False
# A->E       0.11%  99.26%      False
# V->P       0.10%  99.36%      False
# D->F       0.09%  99.45%      False
# F->A       0.09%  99.54%      False
# F->D       0.09%  99.62%      False
# E->F       0.07%  99.69%      False
# F->P       0.06%  99.75%      False
# P->E       0.04%  99.80%      False
# F->E       0.04%  99.84%      False
# P->D       0.03%  99.87%      False
# P->F       0.03%  99.90%      False
# E->P       0.03%  99.92%      False
# P->P       0.03%  99.95%      False
# D->P       0.02%  99.98%      False
# P->A       0.02% 100.00%      False

# %% [markdown]
# ### Validación

# %%
nClusters = 10
seed = 206
nRepetitions = 1000
computeClusterValidation = True
plt.rcParams["figure.figsize"] = [5,3]

# %%
if computeClusterValidation:
    av, st = vf.interClusterDistKMeans(featuresDF, nClusters = nClusters, nRandomStates = nRepetitions, 
                                    seed = seed, plot = True)

# %%
if computeClusterValidation:
    av, st = vf.BICCriterionKMeans(featuresDF, nClusters = nClusters, nRandomStates = nRepetitions, 
                                    seed = seed, plot = True)

# %%
if computeClusterValidation:
    av, st = vf.closestCentroidDistKMeans(featuresDF, nClusters = nClusters, nInit = nRepetitions, 
                                    seed = seed, plot = True)

# %%
if computeClusterValidation:
    plt.figure(figsize=(6,9))
    av, st = vf.silhouetteKMeans(featuresDF, nClusters = nClusters, nInit = nRepetitions, 
                                    seed = seed, plot = True)

# %%
# EVALUATE THE PARAMETERS OF THE MODEL

from sklearn.cluster import KMeans
model = KMeans()

param_grid = {
    'n_clusters' : [4],
    'algorithm' : ['auto', 'full', 'elkan'],
    'init' : ['k-means++', 'random'],
    'n_init' : [20],
    'max_iter' : [100, 200, 300],
    'random_state' : [None]
}


nkFolds = 50
scores, parameters, _ = vf.DeepCrossValidationClustering(featuresDF, 'KMeans', model, param_grid, kfold=nkFolds)

print('\nEVALUATION\n')

vf.evaluateResults(scores, parameters)
# Out:
# KMeans_01 - Tiempo de proceso [s]: 167.643
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.899947175
# Puntuación de validación: -3.39110009221
# Puntuación de test: -3.67172151194
#
#
# KMeans_02 - Tiempo de proceso [s]: 196.450
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.47202852
# Puntuación de validación: -3.38243237584
# Puntuación de test: -4.10236081968
#
#
# KMeans_03 - Tiempo de proceso [s]: 176.715
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.09436903
# Puntuación de validación: -3.37652606895
# Puntuación de test: -4.48266043552
#
#
# KMeans_04 - Tiempo de proceso [s]: 169.936
# KMeans(algorithm='elkan', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.343090524
# Puntuación de validación: -3.39867955361
# Puntuación de test: -3.22705611273
#
#
# KMeans_05 - Tiempo de proceso [s]: 176.287
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.375078462
# Puntuación de validación: -3.40157182688
# Puntuación de test: -3.19344695865
#
#
# KMeans_06 - Tiempo de proceso [s]: 185.783
# KMeans(algorithm='elkan', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.031994133
# Puntuación de validación: -3.39476647661
# Puntuación de test: -3.54004957302
#
#
# KMeans_07 - Tiempo de proceso [s]: 176.053
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.217118999
# Puntuación de validación: -3.39704179345
# Puntuación de test: -3.35505228409
#
#
# KMeans_08 - Tiempo de proceso [s]: 177.927
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.187485321
# Puntuación de validación: -3.39675638332
# Puntuación de test: -3.38106129093
#
#
# KMeans_09 - Tiempo de proceso [s]: 171.107
# KMeans(algorithm='elkan', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.583239275
# Puntuación de validación: -3.40631713696
# Puntuación de test: -2.98468325499
#
#
# KMeans_10 - Tiempo de proceso [s]: 178.422
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.836052901
# Puntuación de validación: -3.38913103167
# Puntuación de test: -3.73623892504
#
#
# KMeans_11 - Tiempo de proceso [s]: 167.198
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=300,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.547337464
# Puntuación de validación: -3.40376519462
# Puntuación de test: -3.02128016029
#
#
# KMeans_12 - Tiempo de proceso [s]: 183.849
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -170.053806349
# Puntuación de validación: -3.41407301702
# Puntuación de test: -2.51317344361
#
#
# KMeans_13 - Tiempo de proceso [s]: 180.193
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.286548383
# Puntuación de validación: -3.37883343925
# Puntuación de test: -4.28644407822
#
#
# KMeans_14 - Tiempo de proceso [s]: 179.913
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.634494263
# Puntuación de validación: -3.40509029749
# Puntuación de test: -2.93647487395
#
#
# KMeans_15 - Tiempo de proceso [s]: 168.854
# KMeans(algorithm='full', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.996629009
# Puntuación de validación: -3.39232461755
# Puntuación de test: -3.57164795044
#
#
# KMeans_16 - Tiempo de proceso [s]: 180.766
# KMeans(algorithm='elkan', copy_x=True, init='random', max_iter=300,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.880005466
# Puntuación de validación: -3.39089318939
# Puntuación de test: -3.68922729614
#
#
# KMeans_17 - Tiempo de proceso [s]: 170.937
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.397876145
# Puntuación de validación: -3.40106460418
# Puntuación de test: -3.17430634047
#
#
# KMeans_18 - Tiempo de proceso [s]: 179.203
# KMeans(algorithm='elkan', copy_x=True, init='k-means++', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.92344404
# Puntuación de validación: -3.39149084673
# Puntuación de test: -3.64897358057
#
#
# KMeans_19 - Tiempo de proceso [s]: 156.954
# KMeans(algorithm='elkan', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.823787184
# Puntuación de validación: -3.39004517909
# Puntuación de test: -3.76188227814
#
#
# KMeans_20 - Tiempo de proceso [s]: 175.377
# KMeans(algorithm='elkan', copy_x=True, init='k-means++', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.513189476
# Puntuación de validación: -3.40325814821
# Puntuación de test: -3.06504382606
#
#
# KMeans_21 - Tiempo de proceso [s]: 187.055
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.218176433
# Puntuación de validación: -3.39651801585
# Puntuación de test: -3.35471894007
#
#
# KMeans_22 - Tiempo de proceso [s]: 168.267
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.625384533
# Puntuación de validación: -3.38526067708
# Puntuación de test: -3.94433819863
#
#
# KMeans_23 - Tiempo de proceso [s]: 156.281
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.35185334
# Puntuación de validación: -3.39965461457
# Puntuación de test: -3.22202284635
#
#
# KMeans_24 - Tiempo de proceso [s]: 167.976
# KMeans(algorithm='elkan', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.957630627
# Puntuación de validación: -3.39313095834
# Puntuación de test: -3.615766921
# KMeans_25 - Tiempo de proceso [s]: 168.810
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=300,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.828863722
# Puntuación de validación: -3.38989763661
# Puntuación de test: -3.73914754108
#
#
# KMeans_26 - Tiempo de proceso [s]: 173.962
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.01119434
# Puntuación de validación: -3.39329261888
# Puntuación de test: -3.55766439051
#
#
# KMeans_27 - Tiempo de proceso [s]: 177.784
# KMeans(algorithm='elkan', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.597168052
# Puntuación de validación: -3.40429629037
# Puntuación de test: -2.97153928547
#
#
# KMeans_28 - Tiempo de proceso [s]: 178.433
# KMeans(algorithm='elkan', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.493883512
# Puntuación de validación: -3.40318007196
# Puntuación de test: -3.07851750469
#
#
# KMeans_29 - Tiempo de proceso [s]: 177.898
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.227900608
# Puntuación de validación: -3.37785067973
# Puntuación de test: -4.34340719215
#
#
# KMeans_30 - Tiempo de proceso [s]: 173.193
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.596829707
# Puntuación de validación: -3.38431701825
# Puntuación de test: -3.97257193409
#
#
# KMeans_31 - Tiempo de proceso [s]: 172.888
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.336369469
# Puntuación de validación: -3.39987828214
# Puntuación de test: -3.23258402208
#
#
# KMeans_32 - Tiempo de proceso [s]: 169.197
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.586053427
# Puntuación de validación: -3.38468922591
# Puntuación de test: -3.98382554058
#
#
# KMeans_33 - Tiempo de proceso [s]: 181.313
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.521371393
# Puntuación de validación: -3.40365559008
# Puntuación de test: -3.0475361507
#
#
# KMeans_34 - Tiempo de proceso [s]: 170.305
# KMeans(algorithm='elkan', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.824068866
# Puntuación de validación: -3.40963427685
# Puntuación de test: -2.74244219053
#
#
# KMeans_35 - Tiempo de proceso [s]: 177.743
# KMeans(algorithm='full', copy_x=True, init='k-means++', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.920421132
# Puntuación de validación: -3.39073577803
# Puntuación de test: -3.65289791488
#
#
# KMeans_36 - Tiempo de proceso [s]: 172.975
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.583049234
# Puntuación de validación: -3.40406165969
# Puntuación de test: -2.98457019537
#
#
# KMeans_37 - Tiempo de proceso [s]: 181.691
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.369878743
# Puntuación de validación: -3.39952686655
# Puntuación de test: -3.20042708772
#
#
# KMeans_38 - Tiempo de proceso [s]: 178.279
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.240028537
# Puntuación de validación: -3.39872734842
# Puntuación de test: -3.3261680059
#
#
# KMeans_39 - Tiempo de proceso [s]: 181.952
# KMeans(algorithm='elkan', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.550248293
# Puntuación de validación: -3.40425788198
# Puntuación de test: -3.01932941172
#
#
# KMeans_40 - Tiempo de proceso [s]: 183.904
# KMeans(algorithm='full', copy_x=True, init='k-means++', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.804148873
# Puntuación de validación: -3.40908627643
# Puntuación de test: -2.76727151656
#
#
# KMeans_41 - Tiempo de proceso [s]: 176.686
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=300,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.724272694
# Puntuación de validación: -3.38764340162
# Puntuación de test: -3.84480699647
#
#
# KMeans_42 - Tiempo de proceso [s]: 166.603
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.130304653
# Puntuación de validación: -3.37669358847
# Puntuación de test: -4.43816064254
#
#
# KMeans_43 - Tiempo de proceso [s]: 181.481
# KMeans(algorithm='elkan', copy_x=True, init='random', max_iter=300,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.271240594
# Puntuación de validación: -3.37978608222
# Puntuación de test: -4.30041903403
#
#
# KMeans_44 - Tiempo de proceso [s]: 173.002
# KMeans(algorithm='full', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.153213061
# Puntuación de validación: -3.39708171497
# Puntuación de test: -3.42578256905
#
#
# KMeans_45 - Tiempo de proceso [s]: 172.514
# KMeans(algorithm='elkan', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.79290392
# Puntuación de validación: -3.39052872839
# Puntuación de test: -3.77663140473
#
#
# KMeans_46 - Tiempo de proceso [s]: 182.086
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -168.594279395
# Puntuación de validación: -3.38598560098
# Puntuación de test: -3.97716011275
#
#
# KMeans_47 - Tiempo de proceso [s]: 178.177
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.635067613
# Puntuación de validación: -3.40607467448
# Puntuación de test: -2.93365005191
#
#
# KMeans_48 - Tiempo de proceso [s]: 183.655
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=300,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.389819161
# Puntuación de validación: -3.40181335139
# Puntuación de test: -3.18555970471
# KMeans_49 - Tiempo de proceso [s]: 161.972
# KMeans(algorithm='elkan', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.35870433
# Puntuación de validación: -3.39965006639
# Puntuación de test: -3.20982551013
#
#
# KMeans_50 - Tiempo de proceso [s]: 157.303
# KMeans(algorithm='full', copy_x=True, init='random', max_iter=100,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)
#
# Puntuación de entrenamiento: -169.478156989
# Puntuación de validación: -3.40244864017
# Puntuación de test: -3.0899692143
#
#
#
# EVALUATION
#
# Train Score:	 -169.105 +- 0.469
# CrossVal Score:	 -3.395 +- 0.009
# Test Score:	 -3.466 +- 0.470
#
#
# ['0.16', '0.16'] ["{'algorithm': 'auto', 'copy_x': True, 'init': 'random', 'max_iter': 100, 'n_clusters': 4, 'n_init': 20, 'n_jobs': 1, 'precompute_distances': 'auto', 'random_state': None, 'tol': 0.0001, 'verbose': 0}", "{'algorithm': 'full', 'copy_x': True, 'init': 'random', 'max_iter': 200, 'n_clusters': 4, 'n_init': 20, 'n_jobs': 1, 'precompute_distances': 'auto', 'random_state': None, 'tol': 0.0001, 'verbose': 0}"]

# %%
nInitializations = 500
nPartitions = 500
test_size = .20

model.set_params(n_clusters = 4, algorithm = 'auto', init = 'random', max_iter = 200, n_init = 20)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=200,
#     n_clusters=4, n_init=20, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
model4 = model.set_params(n_clusters = 4)

model4, bestSeed4, results4 = vf.InitializationSeed(featuresDF, model4, test_size = test_size, seed = seed,
                                nRandomStates = nInitializations, CrossVal = nPartitions)
print('Seed:', bestSeed4)
# Out:
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed: 17.9min
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed: 25.6min
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed: 31.5min
# [Parallel(n_jobs=4)]: Done  53 tasks      | elapsed: 39.9min
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed: 46.6min
# [Parallel(n_jobs=4)]: Done  77 tasks      | elapsed: 57.1min
# [Parallel(n_jobs=4)]: Done  90 tasks      | elapsed: 65.7min
# [Parallel(n_jobs=4)]: Done 105 tasks      | elapsed: 77.0min
# [Parallel(n_jobs=4)]: Done 120 tasks      | elapsed: 86.4min
# [Parallel(n_jobs=4)]: Done 137 tasks      | elapsed: 99.7min
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed: 111.4min
# [Parallel(n_jobs=4)]: Done 173 tasks      | elapsed: 125.6min
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed: 138.7min
# [Parallel(n_jobs=4)]: Done 213 tasks      | elapsed: 154.1min
# [Parallel(n_jobs=4)]: Done 234 tasks      | elapsed: 169.0min
# [Parallel(n_jobs=4)]: Done 257 tasks      | elapsed: 185.7min
# [Parallel(n_jobs=4)]: Done 280 tasks      | elapsed: 201.6min
# [Parallel(n_jobs=4)]: Done 305 tasks      | elapsed: 220.2min
# [Parallel(n_jobs=4)]: Done 330 tasks      | elapsed: 237.6min
# [Parallel(n_jobs=4)]: Done 357 tasks      | elapsed: 257.3min
# [Parallel(n_jobs=4)]: Done 384 tasks      | elapsed: 276.5min
# [Parallel(n_jobs=4)]: Done 413 tasks      | elapsed: 297.5min
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed: 317.6min
# [Parallel(n_jobs=4)]: Done 473 tasks      | elapsed: 340.0min
# [Parallel(n_jobs=4)]: Done 500 out of 500 | elapsed: 358.9min finished
# Error Difference: -111.052500326
# Validation: -30.8123976972
# Seed: [1547, 458]

# %%
model = vf.CreatePartitionAndFitSelectedModel(featuresDF, model4, test_size, bestSeed4[0], bestSeed4[1])
labels = model.predict(featuresDF)
centers = model.cluster_centers_

# %%
cf.plotCentroids(centers, labels, featuresDF.columns, sort = [], avg = False, matrix = True, textThreshold = -.01)

# %%
alpha = 10**-1

# %%
DP, DC = vf.checkClusterPositions(featuresDF, model4, test_size, results4, alpha)
_ =[print("%d%%"%(x[0]*100),x[1],x[2],'\n') for x in DP if (x[0]*100)>2]
# Out:
# 100% [['V->V'], ['A->A', 'A->V', 'E->A', 'F->F', 'Rest'], ['D->D', 'D->V', 'V->D'], ['E->E', 'V->E', 'E->V']] [1547, 458]

# %%
featuresDF.columns
# Out:
# Index(['V->V', 'E->E', 'A->A', 'D->D', 'V->E', 'E->V', 'D->V', 'V->D', 'A->V',
#        'E->A', 'F->F', 'Rest'],
#       dtype='object')
